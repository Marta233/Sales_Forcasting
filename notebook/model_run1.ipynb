# %%
import pandas as pd
import sys
sys.path.insert(0, '/10 A KAI 2/Week 4/Sales_Forcasting/') 
from Scripts.Model_build import SalesForecasting

# %%
from Scripts.Model_Preprocess import ModelPrepro 
from Scripts.EDA import BASICEDA

# %%
file1 = '../Data/train.csv'

# %%
model_building = SalesForecasting(file1)

# %%
# Step 2: Load the data
model_building.load_data()
# Out:
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_build.py:138: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.file_path)
# 2024-09-24 14:36:17,950 - INFO - Data loaded with shape: (1017209, 9)

# %%
# Preprocess the data
model_building.preprocess_data()
# Out:
# 2024-09-24 14:36:18,383 - INFO - Starting data preprocessing for 1017209 rows and 9 columns.
# 2024-09-24 14:36:18,767 - INFO - Descriptive statistics of the dataset:
# 2024-09-24 14:36:18,767 - INFO -                    count                           mean                  min  \
# Store          1017209.0                     558.429727                  1.0
# DayOfWeek      1017209.0                       3.998341                  1.0
# Date             1017209  2014-04-11 01:30:42.846061824  2013-01-01 00:00:00
# Sales          1017209.0                    5773.818972                  0.0
# Customers      1017209.0                     633.145946                  0.0
# Open           1017209.0                       0.830107                  0.0
# Promo          1017209.0                       0.381515                  0.0
# SchoolHoliday  1017209.0                       0.178647                  0.0
#
#                                25%                  50%                  75%  \
# Store                        280.0                558.0                838.0
# DayOfWeek                      2.0                  4.0                  6.0
# Date           2013-08-17 00:00:00  2014-04-02 00:00:00  2014-12-12 00:00:00
# Sales                       3727.0               5744.0               7856.0
# Customers                    405.0                609.0                837.0
# Open                           1.0                  1.0                  1.0
# Promo                          0.0                  0.0                  1.0
# SchoolHoliday                  0.0                  0.0                  0.0
#
#                                max          std
# Store                       1115.0   321.908651
# DayOfWeek                      7.0     1.997391
# Date           2015-07-31 00:00:00          NaN
# Sales                      41551.0  3849.926175
# Customers                   7388.0   464.411734
# Open                           1.0     0.375539
# Promo                          1.0     0.485759
# SchoolHoliday                  1.0     0.383056
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_build.py:63: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['DaysToNextHoliday'].fillna(self.data['DaysToNextHoliday'].mean(), inplace=True)
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_build.py:64: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['DaysAfterLastHoliday'].fillna(self.data['DaysAfterLastHoliday'].mean(), inplace=True)
# 2024-09-24 14:38:55,642 - INFO - Preprocessed data shape: (1017209, 15)
# 2024-09-24 14:38:55,642 - INFO - Available columns after preprocessing: ['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo', 'SchoolHoliday', 'DaysToNextHoliday', 'DaysAfterLastHoliday', 'weekend', 'weekdays', 'Quarter', 'Month', 'Seasons', 'IsStateHoliday']
#          Store  DayOfWeek  Sales  Customers  Open  Promo  SchoolHoliday  \
# 0            1          5   5263        555     1      1              1
# 1            2          5   6064        625     1      1              1
# 2            3          5   8314        821     1      1              1
# 3            4          5  13995       1498     1      1              1
# 4            5          5   4822        559     1      1              1
# ...        ...        ...    ...        ...   ...    ...            ...
# 1017204   1111          2      0          0     0      0              1
# 1017205   1112          2      0          0     0      0              1
# 1017206   1113          2      0          0     0      0              1
# 1017207   1114          2      0          0     0      0              1
# 1017208   1115          2      0          0     0      0              1
#
#          DaysToNextHoliday  DaysAfterLastHoliday  weekend  weekdays  Quarter  \
# 0                19.503275             57.000000        0         1        3
# 1                19.503275             57.000000        0         1        3
# 2                19.503275             57.000000        0         1        3
# 3                19.503275             57.000000        0         1        3
# 4                19.503275             57.000000        0         1        3
# ...                    ...                   ...      ...       ...      ...
# 1017204           5.000000             20.062189        0         1        1
# 1017205           5.000000             20.062189        0         1        1
# 1017206           5.000000             20.062189        0         1        1
# 1017207           5.000000             20.062189        0         1        1
# 1017208           5.000000             20.062189        0         1        1
#
#          Month  Seasons  IsStateHoliday
# 0            7        2               1
# 1            7        2               1
# 2            7        2               1
# 3            7        2               1
# 4            7        2               1
# ...        ...      ...             ...
# 1017204      1        4               1
# 1017205      1        4               1
# 1017206      1        4               1
# 1017207      1        4               1
# 1017208      1        4               1
#
# [1017209 rows x 15 columns]

# %%
model_building.fit_random_forest_model1()
# Out:
# 2024-09-24 14:40:58,382 - INFO - Random Forest model fitting complete.

# %%
model_building.evaluate_model1()
# Out:
# 2024-09-24 14:41:47,347 - INFO - Random Forest - MAE: 294.13885010793746, R^2: 0.9809171267562153

# %%
model_building.save_random_forest_model()
# Out:
# 2024-09-24 14:43:15,482 - INFO - Random Forest model saved as random_forest_model_2024-09-24-14-41-47.pkl
