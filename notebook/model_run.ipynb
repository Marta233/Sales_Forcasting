# %%
import pandas as pd
import sys
sys.path.insert(0, '/10 A KAI 2/Week 4/Sales_Forcasting/') 
from Scripts.Model_Preprocess import SalesForecasting

# %%
from Scripts.Model_Preprocess import ModelPrepro 
from Scripts.EDA import BASICEDA

# %%
file = '../Data/mergedData.csv'

# %%
model_building = SalesForecasting(file)

# %%
# Step 2: Load the data
model_building.load_data()
# Out:
# 2024-09-23 11:52:23,001 - INFO - Data loaded with shape: (1017209, 19)

# %%
# Preprocess the data
model_building.preprocess_data()
# Out:
# 2024-09-23 11:52:23,937 - INFO - Starting data preprocessing for 1017209 rows and 19 columns.
# 2024-09-23 11:52:24,702 - INFO - Descriptive statistics of the dataset:
# 2024-09-23 11:52:24,702 - INFO -                                count                           mean  \
# Unnamed: 0                 1017209.0                       508604.0
# Store                      1017209.0                     558.429727
# CompetitionDistance        1014567.0                    5430.085652
# CompetitionOpenSinceMonth   693861.0                       7.222866
# CompetitionOpenSinceYear    693861.0                    2008.690228
# Promo2                     1017209.0                       0.500564
# Promo2SinceWeek             509178.0                      23.269093
# Promo2SinceYear             509178.0                    2011.752774
# DayOfWeek                  1017209.0                       3.998341
# Date                         1017209  2014-04-11 01:30:42.846061824
# Sales                      1017209.0                    5773.818972
# Customers                  1017209.0                     633.145946
# Open                       1017209.0                       0.830107
# Promo                      1017209.0                       0.381515
# SchoolHoliday              1017209.0                       0.178647
#
#                                            min                  25%  \
# Unnamed: 0                                 0.0             254302.0
# Store                                      1.0                280.0
# CompetitionDistance                       20.0                710.0
# CompetitionOpenSinceMonth                  1.0                  4.0
# CompetitionOpenSinceYear                1900.0               2006.0
# Promo2                                     0.0                  0.0
# Promo2SinceWeek                            1.0                 13.0
# Promo2SinceYear                         2009.0               2011.0
# DayOfWeek                                  1.0                  2.0
# Date                       2013-01-01 00:00:00  2013-08-17 00:00:00
# Sales                                      0.0               3727.0
# Customers                                  0.0                405.0
# Open                                       0.0                  1.0
# Promo                                      0.0                  0.0
# SchoolHoliday                              0.0                  0.0
#
#                                            50%                  75%  \
# Unnamed: 0                            508604.0             762906.0
# Store                                    558.0                838.0
# CompetitionDistance                     2330.0               6890.0
# CompetitionOpenSinceMonth                  8.0                 10.0
# CompetitionOpenSinceYear                2010.0               2013.0
# Promo2                                     1.0                  1.0
# Promo2SinceWeek                           22.0                 37.0
# Promo2SinceYear                         2012.0               2013.0
# DayOfWeek                                  4.0                  6.0
# Date                       2014-04-02 00:00:00  2014-12-12 00:00:00
# Sales                                   5744.0               7856.0
# Customers                                609.0                837.0
# Open                                       1.0                  1.0
# Promo                                      0.0                  1.0
# SchoolHoliday                              0.0                  0.0
#
#                                            max            std
# Unnamed: 0                           1017208.0  293643.089324
# Store                                   1115.0     321.908651
# CompetitionDistance                    75860.0      7715.3237
# CompetitionOpenSinceMonth                 12.0       3.211832
# CompetitionOpenSinceYear                2015.0       5.992644
# Promo2                                     1.0            0.5
# Promo2SinceWeek                           50.0      14.095973
# Promo2SinceYear                         2015.0        1.66287
# DayOfWeek                                  7.0       1.997391
# Date                       2015-07-31 00:00:00            NaN
# Sales                                  41551.0    3849.926175
# Customers                               7388.0     464.411734
# Open                                       1.0       0.375539
# Promo                                      1.0       0.485759
# SchoolHoliday                              1.0       0.383056
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_Preprocess.py:70: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['DaysToNextHoliday'].fillna(self.data['DaysToNextHoliday'].mean(), inplace=True)
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_Preprocess.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['DaysAfterLastHoliday'].fillna(self.data['DaysAfterLastHoliday'].mean(), inplace=True)
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_Preprocess.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['CompetitionDistance'].fillna(self.data['CompetitionDistance'].mean(), inplace=True)
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_Preprocess.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['Sales_lag_1'].fillna(mean_sales_lag_1, inplace=True)
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Model_Preprocess.py:76: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data['Sales_lag_7'].fillna(mean_sales_lag_7, inplace=True)
# 2024-09-23 11:54:50,003 - INFO - One-hot encoding completed.
# 2024-09-23 11:54:50,303 - INFO - Data scaling complete.
#          Store  CompetitionDistance  Promo2  DayOfWeek  Sales  Customers  \
# 0            1            -0.539900       0          5   5263  -0.168269
# 1            1            -0.539900       0          4   5020  -0.187648
# 2            1            -0.539900       0          3   4782  -0.237173
# 3            1            -0.539900       0          2   5011  -0.157502
# 4            1            -0.539900       0          1   6102  -0.045533
# ...        ...                  ...     ...        ...    ...        ...
# 1017204   1115            -0.010394       1          6   4771  -0.633374
# 1017205   1115            -0.010394       1          5   4540  -0.661366
# 1017206   1115            -0.010394       1          4   4297  -0.717351
# 1017207   1115            -0.010394       1          3   3697  -0.706584
# 1017208   1115            -0.010394       1          2      0  -1.363330
#
#          Open  Promo  SchoolHoliday  DaysToNextHoliday  DaysAfterLastHoliday  \
# 0           1      1              1           0.000000          1.034985e+00
# 1           1      1              1           0.000000          9.967955e-01
# 2           1      1              1           0.000000          9.586058e-01
# 3           1      1              1           0.000000          9.204160e-01
# 4           1      1              1           0.000000          8.822262e-01
# ...       ...    ...            ...                ...                   ...
# 1017204     1      0              1          -1.120390         -9.890737e-01
# 1017205     1      0              1          -1.081986         -1.027264e+00
# 1017206     1      0              1          -1.043581         -1.065453e+00
# 1017207     1      0              1          -1.005176         -1.103643e+00
# 1017208     0      0              1          -0.966771          1.492451e-15
#
#          weekend  weekdays  Quarter  Month  Seasons  Sales_lag_1  \
# 0              0         1        3      7        2     0.000000
# 1              0         1        3      7        2    -0.132684
# 2              0         1        3      7        2    -0.195803
# 3              0         1        3      7        2    -0.257622
# 4              0         1        3      7        2    -0.198140
# ...          ...       ...      ...    ...      ...          ...
# 1017204        1         0        1      1        4    -1.499726
# 1017205        0         1        1      1        4    -0.260479
# 1017206        0         1        1      1        4    -0.320481
# 1017207        0         1        1      1        4    -0.383599
# 1017208        0         1        1      1        4    -0.539446
#
#           Sales_lag_7  IsStateHoliday
# 0        2.362376e-16               1
# 1        2.362376e-16               1
# 2        2.362376e-16               1
# 3        2.362376e-16               1
# 4        2.362376e-16               1
# ...               ...             ...
# 1017204 -3.316528e-01               1
# 1017205 -1.641166e-01               1
# 1017206 -1.991823e-01               1
# 1017207 -2.921714e-01               1
# 1017208 -1.378823e-01               1
#
# [1017209 rows x 19 columns]

# %%
model_building.fit_random_forest_model()
# Out:
# Available columns: ['Store', 'CompetitionDistance', 'Promo2', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo', 'SchoolHoliday', 'DaysToNextHoliday', 'DaysAfterLastHoliday', 'weekend', 'weekdays', 'Quarter', 'Month', 'Seasons', 'Sales_lag_1', 'Sales_lag_7', 'IsStateHoliday']
# 2024-09-23 11:59:12,559 - INFO - Random Forest model fitting complete.

# %%
model_building.evaluate_models()
# Out:
# 2024-09-23 01:22:45,625 - INFO - Random Forest - MAE: 389.4489659952222, R^2: 0.9737795811059924

# %%
model_building.fit_random_forest_model1()
# Out:
# Available columns: ['Store', 'CompetitionDistance', 'Promo2', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo', 'SchoolHoliday', 'DaysToNextHoliday', 'DaysAfterLastHoliday', 'weekend', 'weekdays', 'Quarter', 'Month', 'Seasons', 'Sales_lag_1', 'Sales_lag_7']
# 2024-09-23 01:28:52,019 - INFO - Random Forest model fitting complete.

# %%
model_building.evaluate_models1()
# Out:
# 2024-09-23 01:29:56,104 - INFO - Random Forest - MAE: 188.2893934389163, R^2: 0.9935376317066092

# %%
model_building.fit_lstm_model()
# Out:
# d:\10 A KAI 2\Week 4\Sales_Forcasting\myenv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 219s 7ms/step - loss: 9384120.0000
# Epoch 2/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 187s 7ms/step - loss: 5482948.0000
# Epoch 3/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 187s 7ms/step - loss: 4942349.0000
# Epoch 4/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 162s 6ms/step - loss: 4523128.0000
# Epoch 5/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 156s 6ms/step - loss: 5309987.0000
# Epoch 6/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 157s 6ms/step - loss: 5132016.0000
# Epoch 7/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 156s 6ms/step - loss: 4800846.0000
# Epoch 8/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 155s 6ms/step - loss: 4636008.0000
# Epoch 9/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 9044s 356ms/step - loss: 4802592.5000
# Epoch 10/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 156s 6ms/step - loss: 4719508.0000
# Epoch 11/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 154s 6ms/step - loss: 4564759.0000
# Epoch 12/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 157s 6ms/step - loss: 4437214.0000
# Epoch 13/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 154s 6ms/step - loss: 4382663.0000
# Epoch 14/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 157s 6ms/step - loss: 4427060.0000
# Epoch 15/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 210s 7ms/step - loss: 4928332.0000
# Epoch 16/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 165s 6ms/step - loss: 4474051.0000
# Epoch 17/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 169s 7ms/step - loss: 4421812.0000
# Epoch 18/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 171s 7ms/step - loss: 5118974.5000
# Epoch 19/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 173s 7ms/step - loss: 4655325.5000
# Epoch 20/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 173s 7ms/step - loss: 4738299.0000
# Epoch 21/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 209s 7ms/step - loss: 4613728.5000
# Epoch 22/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 170s 7ms/step - loss: 4427886.5000
# Epoch 23/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 174s 7ms/step - loss: 4407724.0000
# Epoch 24/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 174s 7ms/step - loss: 4514994.5000
# Epoch 25/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 168s 7ms/step - loss: 4363054.0000
# Epoch 26/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 164s 6ms/step - loss: 4326301.0000
# Epoch 27/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 171s 7ms/step - loss: 4435582.0000
# Epoch 28/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 169s 7ms/step - loss: 4475724.5000
# Epoch 29/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 158s 6ms/step - loss: 4300540.5000
# Epoch 30/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 161s 6ms/step - loss: 4394458.0000
# Epoch 31/100
# 25431/25431 ━━━━━━━━━━━━━━━━━━━━ 200s 6ms/step - loss: 4246805.5000
# Epoch 32/100
# 17315/25431 ━━━━━━━━━━━━━━━━━━━━ 53s 7ms/step - loss: 4321621.5000

# %%
model_building.evaluate_models_lstm()
