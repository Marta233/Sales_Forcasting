# %%
# Usage
import sys
import pandas as pd
sys.path.insert(0, '/10 A KAI 2/Week 4/Sales_Forcasting/')

# %%
from Scripts.Deep_model import SalesForecasting 
filee = '../Data/train.csv'  # Replace this with your actual file path

# %%
sales_forecasting = SalesForecasting(filee)

# %%
# Load, preprocess, fit, evaluate, and save the LSTM model
sales_forecasting.load_data()
# Out:
# d:\10 A KAI 2/Week 4/Sales_Forcasting\Scripts\Deep_model.py:83: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(self.file_path)
# 2024-09-24 00:38:20,479 - INFO - Data loaded with shape: (1017209, 9)

# %%
sales_forecasting.preprocess_data()
# Out:
# 2024-09-24 00:38:20,670 - INFO - Starting data preprocessing for 1017209 rows and 9 columns.
# 2024-09-24 00:38:20,985 - INFO - Descriptive statistics of the dataset:
# 2024-09-24 00:38:20,985 - INFO -                    count                           mean                  min  \
# Store          1017209.0                     558.429727                  1.0
# DayOfWeek      1017209.0                       3.998341                  1.0
# Date             1017209  2014-04-11 01:30:42.846061824  2013-01-01 00:00:00
# Sales          1017209.0                    5773.818972                  0.0
# Customers      1017209.0                     633.145946                  0.0
# Open           1017209.0                       0.830107                  0.0
# Promo          1017209.0                       0.381515                  0.0
# SchoolHoliday  1017209.0                       0.178647                  0.0
#
#                                25%                  50%                  75%  \
# ...

# %%
sales_forecasting.create_lstm_dataset()
# Out:
# (array([[[1.000e+00, 5.000e+00, 5.550e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          [2.000e+00, 5.000e+00, 6.250e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          [3.000e+00, 5.000e+00, 8.210e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          ...,
#          [8.000e+00, 5.000e+00, 8.330e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          [9.000e+00, 5.000e+00, 6.870e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          [1.000e+01, 5.000e+00, 6.810e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00]],
#
#         [[2.000e+00, 5.000e+00, 6.250e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          [3.000e+00, 5.000e+00, 8.210e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          [4.000e+00, 5.000e+00, 1.498e+03, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
#          ...,
#          [9.000e+00, 5.000e+00, 6.870e+02, ..., 7.000e+00, 2.000e+00,
#           1.000e+00],
# ...

# %%
sales_forecasting.fit_lstm_model()
# Out:
# d:\10 A KAI 2\Week 4\Sales_Forcasting\myenv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 428s 12ms/step - loss: 46218764.0000
# Epoch 2/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 405s 10ms/step - loss: 39342620.0000
# Epoch 3/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 442s 14ms/step - loss: 32931778.0000
# Epoch 4/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 866s 19ms/step - loss: 27490206.0000
# Epoch 5/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 286s 9ms/step - loss: 22658270.0000
# Epoch 6/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 257s 8ms/step - loss: 18637930.0000
# Epoch 7/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 11031s 347ms/step - loss: 15356164.0000
# Epoch 8/20
# 31788/31788 ━━━━━━━━━━━━━━━━━━━━ 5944s 186ms/step - loss: 12785875.0000
# ...

# %%
sales_forecasting.evaluate_lstm_model()

# %%
sales_forecasting.save_lstm_model()
